# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/-Employee-Management-Payroll-System-Console-Based-/blob/main/MODULE_4_Performance_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Performance Evaluation

# %%
def performance_evaluation():
    total = 0

    for i in range(3):
        rating = int(input("Enter rating (1–5): "))
        total += rating

    avg = total / 3
    print("Average Rating:", avg)

    if avg >= 4:
        print("Performance: Excellent")
    elif avg >= 3:
        print("Performance: Good")
    else:
        print("Performance: Needs Improvement")

performance_evaluation()
# Out:
# Enter rating (1–5): 4
# Enter rating (1–5): 2
# Enter rating (1–5): 1
# Average Rating: 2.3333333333333335
# Performance: Needs Improvement
