# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/-Employee-Management-Payroll-System-Console-Based-/blob/main/Main_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def login(username, password):
    print(f"Attempting to log in with username: {username} and password: {password}")
    # In a real system, you'd check against a database
    if username == "Tanuja" and password == "0987":
        print("Login successful!")
        return True
    else:
        print("Login failed: Invalid credentials.")
        return False

def register_employee():
    print("Registering new employee...")
    # Placeholder for employee registration logic
    employee_data = {
        "name": input("Enter employee name: "),
        "id": input("Enter employee ID: "),
        "salary": float(input("Enter employee salary: ")) # Assuming salary is a float
    }
    print(f"Employee {employee_data['name']} registered.")
    return employee_data

def attendance_management():
    print("Managing attendance...")
    # Placeholder for attendance logic, returning a dummy value
    try:
        present_days = int(input("Enter number of present days: "))
    except ValueError:
        print("Invalid input, defaulting to 20 present days.")
        present_days = 20
    return present_days

def calculate_salary(base_salary, present_days):
    print(f"Calculating salary for {present_days} days...")
    # Simple salary calculation example
    daily_rate = base_salary / 30 # Assuming monthly salary
    final_salary = daily_rate * present_days
    print(f"Calculated salary: {final_salary:.2f}")
    return final_salary

def performance_evaluation():
    print("Performing performance evaluation...")
    # Placeholder for performance evaluation logic
    print("Evaluation complete.")

print("=== Digital Dreams Employee System ===")

user = input("Enter Username: ")
pwd = input("Enter Password: ")

if login(user, pwd):

    employee = register_employee()

    if employee:
        present_days = attendance_management()
        calculate_salary(employee["salary"], present_days)
        performance_evaluation()

else:
    print("Program Terminated")
# Out:
# === Digital Dreams Employee System ===
# Enter Username: Tanuja
# Enter Password: 0987
# Attempting to log in with username: Tanuja and password: 0987
# Login successful!
# Registering new employee...
# Enter employee name: Tanu
# Enter employee ID: DD112
# Enter employee salary: 30000
# Employee Tanu registered.
# Managing attendance...
# Enter number of present days: 20
# Calculating salary for 20 days...
# Calculated salary: 20000.00
# Performing performance evaluation...
# Evaluation complete.
