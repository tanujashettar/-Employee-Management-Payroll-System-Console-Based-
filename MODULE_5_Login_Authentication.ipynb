# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/-Employee-Management-Payroll-System-Console-Based-/blob/main/MODULE_5_Login_Authentication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Login Authentication

# %%
def login(username, password):
    if username == "dd_admin" and password == "dd@123":
        print("Login Successful")
    else:
        print("Access Denied")

# %%
user = "dd_admin"
pwd = "dd@123"
login(user, pwd)
# Out:
# Login Successful
