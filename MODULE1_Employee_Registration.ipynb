# %% [markdown]
# <a href="https://colab.research.google.com/github/tanujashettar/-Employee-Management-Payroll-System-Console-Based-/blob/main/MODULE1_Employee_Registration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Employee Registration

# %%
def register_employee():
    print("\n--- Employee Registration ---")

    emp_id = input("Enter Employee ID: ")
    name = input("Enter Employee Name: ")
    age = int(input("Enter Age: "))
    department = input("Enter Department: ")
    basic_salary = float(input("Enter Basic Salary: "))

    if age < 18:
        print("Error: Employee age must be 18 or above.")
        return

    if basic_salary <= 0:
        print("Error: Basic salary must be greater than 0.")
        return

    print("Employee registered successfully")

# %%
register_employee()
# Out:
# --- Employee Registration ---
# Enter Employee ID: DD112
# Enter Employee Name: Tanuja
# Enter Age: 20
# Enter Department: IT
# Enter Basic Salary: 30000
# Employee registered successfully
